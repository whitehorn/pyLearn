# %% [markdown]
# # P419 B Справочные материалы по python
#
# Автор: Шабанов Павел Александрович
#
# Email: pa.shabanov@gmail.com
#
# **Дата последнего обновления: 09.10.2018**
#
# URLs:
#
# + [Головной сайт python](http://www.python.org/)
#
# + [Conda cheat sheet - шпаргалка по дистр. conda](https://conda.io/docs/_downloads/conda-cheatsheet.pdf)
#
# + [DataCamp cheat sheet - шпаргалка по пакетам python](https://www.datacamp.com/community/data-science-cheatsheets)
#
# Мои проекты по python:
#
# + [Заметки по программированию в науках о Земле](http://progeoru.blogspot.ru/);
#
# + [Учебник "Научная графика в python"](https://github.com/whitehorn/Scientific_graphics_in_python);
#
#
# **Дата последнего обновления: 05.02.2018**
#
# ### Цель:
#
# + собрать актуальные ссылки на учебные материалы по python.
#
# ## Учебники
#
# 1. [Марк Лутц]()
#
# 1. [Swaroop C.H. "Укус питона"](http://www.swaroopch.com/notes/python/) - отличный бесплатный старт в изучении основ python (перевод на русском языке);
#
# 2. Прохорёнок Н.А. "Python самое необходимое", Санкт-Петербург, БХВ-Петербург, 2010. [Ознакомительная версия](http://www.bookland.com/download/1/10/107848/sample.pdf) в pdf.
#
# 3. Учебник Шабанова П.А. ["Научная графика в python"](https://github.com/whitehorn/Scientific_graphics_in_python) (rus).
#
# ## Документация
#
# Документация [стандартных библиотек python](https://www.python.org/doc/);
#
# ### Правила оформления python-кода
#
# 1. [pep 8](https://www.python.org/dev/peps/pep-0008/) в оригинале;
# 2. [pep8 в переводе](http://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html);
# 3. [Советы Google по кодированию, часть 1,](http://habrahabr.ru/post/179271/) на языке Python;
# 4. [Советы Google по кодированию, часть 2,](http://habrahabr.ru/post/180509/) на языке Python.
#
# ## Сайты, посвящённые python
#
# 1. Замечательный сайт ["Python 3 для начинающих"](http://pythonworld.ru/);
#
# 2. [Основы программирования на python](http://younglinux.info/python.php) для школьников на Younglinux;
#
# 3. [Заметки по программированию](http://progeoru.blogspot.ru/) в науках о Земле;
#
# 4. Русскоязычный проект океанографа Николая Кодунова ["Записки океанолога"](http://koldunov.net/), посвящённый применению python в океанологии и науках о Земле;
#
# 5. Англоязычный проект океанографа Николая Кодунова ["EarthPy"](http://earthpy.org/), посвящённый применению python в океанологии и науках о Земле;
#
# 6. [Русскоязычный форум](http://python.su/forum/) [отечественного сайта](http://python.su/) по программированию на python;
#
# 7. Website to learn [Python Programming Language for ocean- and marine-science applications](http://oceanpython.org/) and to share Python code (eng).
#
# ### Пакеты для научной работы
#
# **UPD: Установка сторонних модулей стала намного проще для конечных пользователей после интеграции pip в python . Информация, приведённая ниже, носит ознакомительный характер и ведёт на веб-страницы с описанием функционала того или иного модуля**
#
# 1. [Numpy](http://www.numpy.org/) - улучшенный модуль для математических вычислений;
#
# 2. [Scipy](http://scipy.org/) - пакет для научных вычислений, библиотека численного анализа;
#
# 3. [Pandas](http://pandas.pydata.org/) - пакет для эффективной работы с таблицами и временными рядами;
#
# 4. [Matplotlib](http://www.matplotlib.org/) - графическая библиотека для получения графики анализа данных высокого качества;
#
# 5. [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/tutorial/distributions.html) - пакет для быстрой статистической обработки и визуализации данных;
#
# 6. [Basemap](http://matplotlib.org/basemap/) - модуль, поддерживающий работу с картографическими проекциями и shape-файлами (не развивается. Слился с проектом Cartopy);
# *. Обучающие материалы (eng.) по работе с Basemap;
#
# 7. [Cartopy](https://scitools.org.uk/cartopy/docs/latest/) - модуль, поддерживающий работу с картографическими проекциями и shape-файлами (развивается. Поглотил проект Basemap;
#
# 8. [Bokeh](https://bokeh.pydata.org/en/latest/) - библиотека для презентации, быстрой статистической обработки и интерактивной визуализации данных, ориентированная на современные веб-браузеры.
#
# ## Онлайн курсы
#
# #### Coursera
#
# 1. [Курсы с использованием python на Coursera](https://www.coursera.org/specializations/python) (eng);
# 2. [Математика и Python для анализа данных (Yandex)](https://www.coursera.org/learn/mathematics-and-python) (rus);
#
# #### Stepic
#
# 1. [Курсы с использованием python на Stepic](https://stepic.org/search?q=python);
# 2. Курс ["Программирование на python"](https://stepic.org/course/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5-%D0%BD%D0%B0-Python-67) (rus) на базе программы [Института биоинформатики](http://bioinformaticsinstitute.ru/).
#
# #### Edx
#
# + [Курсы с использованием python на Edx](https://www.edx.org/course?search_query=python) (eng);
#
# #### Codecademy
#
# + [Курсы с использованием python на Codecademy](https://www.codecademy.com/learn/python) (eng);
#
# #### Интуит
#
# + [Курсы с использованием python на Edx](http://www.intuit.ru/studies/courses?service=0&option_id=13&service_path=1) (rus);

# %% [markdown]
# ## Обучающие видео

# %%
from IPython.lib.display import YouTubeVideo
YouTubeLectures = ['KdZ4HF1SrFs', 'ZgSx3yH7sJI', 'b8m9uRMpKJk']

# Лекция 1 
# курс: Информатика. Алгоритмы и структуры данных на Python 3.
# прочитана 19.09.2017
# лектор: Хирьянов Тимофей Фёдорович
YouTubeVideo(YouTubeLectures[0])

# %%
from IPython.lib.display import YouTubeVideo
YouTubeLectures = ['KdZ4HF1SrFs', 'ZgSx3yH7sJI', 'b8m9uRMpKJk']

# Лекция 2
# курс: Информатика. Алгоритмы и структуры данных на Python 3.
# прочитана 19.09.2017
# лектор: Хирьянов Тимофей Фёдорович
YouTubeVideo(YouTubeLectures[1])

# %%
from IPython.lib.display import YouTubeVideo
YouTubeLectures = ['KdZ4HF1SrFs', 'ZgSx3yH7sJI', 'b8m9uRMpKJk']

# Лекция 3
# курс: Информатика. Алгоритмы и структуры данных на Python 3.
# прочитана 19.09.2017
# лектор: Хирьянов Тимофей Фёдорович
YouTubeVideo(YouTubeLectures[2])

# %% [markdown]
# ## Заключение
#
# ### Python Дзен
#
# Just type "import this"

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# + Красивое лучше, чем уродливое.
# + Явное лучше, чем неявное.
# + Простое лучше, чем сложное.
# + **Сложное лучше, чем запутанное**.
# + Плоское лучше, чем вложенное.
# + Разреженное лучше, чем плотное.
# + Читаемость имеет значение.
# + Особые случаи не настолько особые, чтобы нарушать правила.
# + При этом практичность важнее безупречности.
# + Ошибки никогда не должны замалчиваться.
# + Если не замалчиваются явно.
# + Встретив двусмысленность, отбрось искушение угадать.
# + **Должен существовать один — и, желательно, только один — очевидный способ сделать это**.
# + Хотя он поначалу может быть и не очевиден, если вы не голландец (Гвидо ван Россум -голландец).
# + Сейчас лучше, чем никогда.
# + Хотя никогда зачастую лучше, чем прямо сейчас.
# + Если реализацию сложно объяснить — идея плоха.
# + Если реализацию легко объяснить — идея, возможно, хороша.
# + Пространства имён — отличная штука! Будем делать их побольше!
